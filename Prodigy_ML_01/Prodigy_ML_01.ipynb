# %% [markdown]
# <a href="https://colab.research.google.com/github/kushagrasharma-13/Prodigy_ML_01/blob/main/Prodigy_ML_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Linear Regression on Salary Dataset
#
# Correlation
#
# Mean Sqaured Error, Variance Score, R2 Score

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split as tts
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import mean_squared_error as MSE, explained_variance_score as EVS, r2_score

# %%
dataset = pd.read_csv("/content/Housing.csv")
dataset
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0                no             yes        2      yes        furnished
# 1                no             yes        3       no        furnished
# 2                no              no        2      yes   semi-furnished
# 3                no             yes        3      yes        furnished
# 4                no             yes        2       no        furnished
# ..              ...             ...      ...      ...              ...
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished
#
# [545 rows x 13 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
dataset.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
corr = dataset.corr()
corr.style.background_gradient(cmap = 'coolwarm')
# Out:
# <ipython-input-36-ffd37e1235a7>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = dataset.corr()
# <style type="text/css">
# #T_c77f8_row0_col0, #T_c77f8_row1_col1, #T_c77f8_row2_col2, #T_c77f8_row3_col3, #T_c77f8_row4_col4, #T_c77f8_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c77f8_row0_col1 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_c77f8_row0_col2 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_c77f8_row0_col3 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_c77f8_row0_col4 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_c77f8_row0_col5 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_c77f8_row1_col0 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_c77f8_row1_col2 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_c77f8_row1_col3 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_c77f8_row1_col4 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_c77f8_row1_col5 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_c77f8_row2_col0, #T_c77f8_row4_col1, #T_c77f8_row4_col5, #T_c77f8_row5_col2, #T_c77f8_row5_col3, #T_c77f8_row5_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c77f8_row2_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_c77f8_row2_col3, #T_c77f8_row3_col0 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_c77f8_row2_col4 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_c77f8_row2_col5 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_c77f8_row3_col1 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_c77f8_row3_col2 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_c77f8_row3_col4, #T_c77f8_row5_col1 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_c77f8_row3_col5 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_c77f8_row4_col0 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_c77f8_row4_col2 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_c77f8_row4_col3 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_c77f8_row5_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c77f8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c77f8_level0_col0" class="col_heading level0 col0" >price</th>
#       <th id="T_c77f8_level0_col1" class="col_heading level0 col1" >area</th>
#       <th id="T_c77f8_level0_col2" class="col_heading level0 col2" >bedrooms</th>
#       <th id="T_c77f8_level0_col3" class="col_heading level0 col3" >bathrooms</th>
#       <th id="T_c77f8_level0_col4" class="col_heading level0 col4" >stories</th>
#       <th id="T_c77f8_level0_col5" class="col_heading level0 col5" >parking</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c77f8_level0_row0" class="row_heading level0 row0" >price</th>
#       <td id="T_c77f8_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_c77f8_row0_col1" class="data row0 col1" >0.535997</td>
#       <td id="T_c77f8_row0_col2" class="data row0 col2" >0.366494</td>
#       <td id="T_c77f8_row0_col3" class="data row0 col3" >0.517545</td>
#       <td id="T_c77f8_row0_col4" class="data row0 col4" >0.420712</td>
#       <td id="T_c77f8_row0_col5" class="data row0 col5" >0.384394</td>
#     </tr>
#     <tr>
#       <th id="T_c77f8_level0_row1" class="row_heading level0 row1" >area</th>
#       <td id="T_c77f8_row1_col0" class="data row1 col0" >0.535997</td>
#       <td id="T_c77f8_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_c77f8_row1_col2" class="data row1 col2" >0.151858</td>
#       <td id="T_c77f8_row1_col3" class="data row1 col3" >0.193820</td>
#       <td id="T_c77f8_row1_col4" class="data row1 col4" >0.083996</td>
#       <td id="T_c77f8_row1_col5" class="data row1 col5" >0.352980</td>
#     </tr>
#     <tr>
#       <th id="T_c77f8_level0_row2" class="row_heading level0 row2" >bedrooms</th>
#       <td id="T_c77f8_row2_col0" class="data row2 col0" >0.366494</td>
#       <td id="T_c77f8_row2_col1" class="data row2 col1" >0.151858</td>
#       <td id="T_c77f8_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_c77f8_row2_col3" class="data row2 col3" >0.373930</td>
#       <td id="T_c77f8_row2_col4" class="data row2 col4" >0.408564</td>
#       <td id="T_c77f8_row2_col5" class="data row2 col5" >0.139270</td>
#     </tr>
#     <tr>
#       <th id="T_c77f8_level0_row3" class="row_heading level0 row3" >bathrooms</th>
#       <td id="T_c77f8_row3_col0" class="data row3 col0" >0.517545</td>
#       <td id="T_c77f8_row3_col1" class="data row3 col1" >0.193820</td>
#       <td id="T_c77f8_row3_col2" class="data row3 col2" >0.373930</td>
#       <td id="T_c77f8_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_c77f8_row3_col4" class="data row3 col4" >0.326165</td>
#       <td id="T_c77f8_row3_col5" class="data row3 col5" >0.177496</td>
#     </tr>
#     <tr>
#       <th id="T_c77f8_level0_row4" class="row_heading level0 row4" >stories</th>
#       <td id="T_c77f8_row4_col0" class="data row4 col0" >0.420712</td>
#       <td id="T_c77f8_row4_col1" class="data row4 col1" >0.083996</td>
#       <td id="T_c77f8_row4_col2" class="data row4 col2" >0.408564</td>
#       <td id="T_c77f8_row4_col3" class="data row4 col3" >0.326165</td>
#       <td id="T_c77f8_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_c77f8_row4_col5" class="data row4 col5" >0.045547</td>
#     </tr>
#     <tr>
#       <th id="T_c77f8_level0_row5" class="row_heading level0 row5" >parking</th>
#       <td id="T_c77f8_row5_col0" class="data row5 col0" >0.384394</td>
#       <td id="T_c77f8_row5_col1" class="data row5 col1" >0.352980</td>
#       <td id="T_c77f8_row5_col2" class="data row5 col2" >0.139270</td>
#       <td id="T_c77f8_row5_col3" class="data row5 col3" >0.177496</td>
#       <td id="T_c77f8_row5_col4" class="data row5 col4" >0.045547</td>
#       <td id="T_c77f8_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Variations for loading independent variable

# %%
x = dataset.iloc[:,1:4].values
print(x.ndim)
# Out:
# 2

# %%
y = dataset["price"].values
print(y.ndim)
# Out:
# 1

# %%
x_train, x_test, y_train, y_test = tts(x, y, test_size=0.3, random_state=0)

# %%
LR = LinearRegression()
LR.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = LR.predict(x_test)

# %%
diff = y_test-y_pred

# %%
LR_df = pd.concat([pd.Series(y_pred), pd.Series(y_test),pd.Series(diff)], axis=1)
LR_df.columns = ['Prediction', 'Test', 'Difference']
LR_df
# Out:
#        Prediction     Test    Difference
# 0    3.959099e+06  4585000  6.259012e+05
# 1    6.297402e+06  6083000 -2.144020e+05
# 2    4.242278e+06  4007500 -2.347785e+05
# 3    7.279070e+06  6930000 -3.490696e+05
# 4    4.325492e+06  2940000 -1.385492e+06
# ..            ...      ...           ...
# 159  3.850668e+06  2940000 -9.106678e+05
# 160  3.959099e+06  2653000 -1.306099e+06
# 161  3.688655e+06  3836000  1.473455e+05
# 162  6.047508e+06  4760000 -1.287508e+06
# 163  4.791235e+06  7962500  3.171265e+06
#
# [164 rows x 3 columns]

# %%
print("Root Mean Squared Error: ", round(np.sqrt(MSE(y_test, y_pred)), 2))
print("Variance Score: ", round(EVS(y_test, y_pred), 2))
print("R Square Score: ", round(r2_score(y_test, y_pred), 2))
# Out:
# Root Mean Squared Error:  1311537.47
# Variance Score:  0.51
# R Square Score:  0.5
